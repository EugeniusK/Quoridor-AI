# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("data/2023-09-11_12-22-55-100.csv")
df2 = pd.read_csv("data/2023-09-11_12-23-00-100.csv")
df3 = pd.read_csv("data/2023-09-11_12-25-26-100.csv")

plt.figure(dpi=100)
# df1.describe()
# df = pd.DataFrame(np.random.randn(1000, 4), columns=list("ABCD"))
df1
df1.query('type_board == 1')['time_taken'].head(100).plot(kind='line', title='Time taken vs Actions taken', legend=True)
df1.query('type_board == 2')['time_taken'].head(100).plot(kind='line', legend=True)
df1.query('type_board == 3')['time_taken'].head(100).plot(kind='line', legend=True)
df1.query('type_board == 4')['time_taken'].head(100).plot(kind='line', legend=True)
df2.query('type_board == 1')['time_taken'].head(100).plot(kind='line', legend=True)
df2.query('type_board == 2')['time_taken'].head(100).plot(kind='line', legend=True)
df2.query('type_board == 3')['time_taken'].head(100).plot(kind='line', legend=True)
df2.query('type_board == 4')['time_taken'].head(100).plot(kind='line', legend=True)
df3.query('type_board == 1')['time_taken'].head(100).plot(kind='line', legend=True)
df3.query('type_board == 2')['time_taken'].head(100).plot(kind='line', legend=True)
df3.query('type_board == 3')['time_taken'].head(100).plot(kind='line', legend=True)
df3.query('type_board == 4')['time_taken'].head(100).plot(kind='line', legend=True)
plt.legend(['StaticGraph1', 'DynamicGraph1', 'PartialBitboard1', 'FullBitboard1', 'StaticGraph2', 'DynamicGraph2', 'PartialBitboard2', 'FullBitboard2', 'StaticGraph3', 'DynamicGraph3', 'PartialBitboard3', 'FullBitboard3'])

# %%
plt.figure()

df3.query('type_board==1').groupby('num_walls')['time_taken'].mean().plot()
df3.query('type_board==2').groupby('num_walls')['time_taken'].mean().plot()
df3.query('type_board==3').groupby('num_walls')['time_taken'].mean().plot()
df3.query('type_board==4').groupby('num_walls')['time_taken'].mean().plot()

plt.legend(['StaticGraph', 'DynamicGraph', 'PartialBitboard', 'FullBitboard'])
