# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("data/2023-09-22_04-33-02-10.csv") # BFS
df2 = pd.read_csv("data/2023-09-22_04-33-04-10.csv") # DFS
df3 = pd.read_csv("data/2023-09-22_04-33-06-10.csv") # GBFS
df4 = pd.read_csv("data/2023-09-22_04-33-08-10.csv") # A*

df5 = pd.read_csv("data/2023-09-22_04-38-53-10000.csv") # BFS
df6 = pd.read_csv("data/2023-09-22_04-47-40-10000.csv") # DFS
df7 = pd.read_csv("data/2023-09-22_04-52-34-10000.csv") # GBFS
df8 = pd.read_csv("data/2023-09-22_05-00-08-10000.csv") # A*

# %%
plt.figure(dpi=250)
df1.query('type_board == 1')['time_taken'].head(100).plot(kind='line', title='Time taken vs Actions taken', legend=True)
df1.query('type_board == 2')['time_taken'].head(100).plot(kind='line', legend=True)
df1.query('type_board == 3')['time_taken'].head(100).plot(kind='line', legend=True)
df1.query('type_board == 4')['time_taken'].head(100).plot(kind='line', legend=True)

plt.legend(['StaticGraph', 'DynamicGraph', 'PartialBitboard', 'FullBitboard'])

# %% [markdown]
# Graph 6 is based on Graph 3 (bfs_candidate_2) but uses static variables which should in theory reduce initialisation and allocation overhead.
# However, in reality, there is little to no difference in performance. So Graph 3 will be used due to its safety.

# %%
# plt.figure()

# df1.query('type_board==1').groupby('num_walls')['time_taken'].mean().plot()
# df2.query('type_board==1').groupby('num_walls')['time_taken'].mean().plot()
# df3.query('type_board==1').groupby('num_walls')['time_taken'].mean().plot()
# df4.query('type_board==1').groupby('num_walls')['time_taken'].mean().plot()

# plt.legend(['BFS', 'DFS', 'GBFS', 'A*'])

fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(2,2)
fig.set_figheight(10)
fig.set_figwidth(16)
ax1.plot(df1.query('type_board==1').head(1000).groupby('num_walls')['time_taken'].mean())
ax1.plot(df2.query('type_board==1').head(1000).groupby('num_walls')['time_taken'].mean())
ax1.plot(df3.query('type_board==1').head(1000).groupby('num_walls')['time_taken'].mean())
ax1.plot(df4.query('type_board==1').head(1000).groupby('num_walls')['time_taken'].mean())
ax1.legend(['BFS', 'DFS', 'GBFS', 'A*'])
ax2.plot(df1.query('type_board==2').head(1000).groupby('num_walls')['time_taken'].mean())
ax2.plot(df2.query('type_board==2').head(1000).groupby('num_walls')['time_taken'].mean())
ax2.plot(df3.query('type_board==2').head(1000).groupby('num_walls')['time_taken'].mean())
ax2.plot(df4.query('type_board==2').head(1000).groupby('num_walls')['time_taken'].mean())
ax2.legend(['BFS', 'DFS', 'GBFS', 'A*'])
ax3.plot(df1.query('type_board==3').head(1000).groupby('num_walls')['time_taken'].mean())
ax3.plot(df2.query('type_board==3').head(1000).groupby('num_walls')['time_taken'].mean())
ax3.plot(df3.query('type_board==3').head(1000).groupby('num_walls')['time_taken'].mean())
ax3.plot(df4.query('type_board==3').head(1000).groupby('num_walls')['time_taken'].mean())
ax3.legend(['BFS', 'DFS', 'GBFS', 'A*'])
ax4.plot(df1.query('type_board==4').head(1000).groupby('num_walls')['time_taken'].mean())
ax4.plot(df2.query('type_board==4').head(1000).groupby('num_walls')['time_taken'].mean())
ax4.plot(df3.query('type_board==4').head(1000).groupby('num_walls')['time_taken'].mean())
ax4.plot(df4.query('type_board==4').head(1000).groupby('num_walls')['time_taken'].mean())
ax4.legend(['BFS', 'DFS', 'GBFS', 'A*'])

# %%
fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(2,2)
fig.set_figheight(10)
fig.set_figwidth(16)
ax1.plot(df5.query('type_board==1').head(1000).groupby('num_walls')['time_taken'].mean())
ax1.plot(df6.query('type_board==1').head(1000).groupby('num_walls')['time_taken'].mean())
ax1.plot(df7.query('type_board==1').head(1000).groupby('num_walls')['time_taken'].mean())
ax1.plot(df8.query('type_board==1').head(1000).groupby('num_walls')['time_taken'].mean())
ax1.legend(['BFS', 'DFS', 'GBFS', 'A*'])
ax2.plot(df5.query('type_board==2').head(1000).groupby('num_walls')['time_taken'].mean())
ax2.plot(df6.query('type_board==2').head(1000).groupby('num_walls')['time_taken'].mean())
ax2.plot(df7.query('type_board==2').head(1000).groupby('num_walls')['time_taken'].mean())
ax2.plot(df8.query('type_board==2').head(1000).groupby('num_walls')['time_taken'].mean())
ax2.legend(['BFS', 'DFS', 'GBFS', 'A*'])
ax3.plot(df5.query('type_board==3').head(1000).groupby('num_walls')['time_taken'].mean())
ax3.plot(df6.query('type_board==3').head(1000).groupby('num_walls')['time_taken'].mean())
ax3.plot(df7.query('type_board==3').head(1000).groupby('num_walls')['time_taken'].mean())
ax3.plot(df8.query('type_board==3').head(1000).groupby('num_walls')['time_taken'].mean())
ax3.legend(['BFS', 'DFS', 'GBFS', 'A*'])
ax4.plot(df5.query('type_board==4').head(1000).groupby('num_walls')['time_taken'].mean())
ax4.plot(df6.query('type_board==4').head(1000).groupby('num_walls')['time_taken'].mean())
ax4.plot(df7.query('type_board==4').head(1000).groupby('num_walls')['time_taken'].mean())
ax4.plot(df8.query('type_board==4').head(1000).groupby('num_walls')['time_taken'].mean())
ax4.legend(['BFS', 'DFS', 'GBFS', 'A*'])
